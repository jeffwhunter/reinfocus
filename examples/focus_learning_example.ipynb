# %%
import numpy as np

from gymnasium.wrappers.time_limit import TimeLimit
from sb3_contrib import RecurrentPPO
from stable_baselines3 import PPO
from stable_baselines3.common.base_class import BaseAlgorithm
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.vec_env import VecEnv, VecFrameStack

import reinfocus.learning.focus_environment as env

# %%
def make_env(observable_type: env.ObservableType = env.ObservableType.FULL):
    base_env = env.FocusEnvironment(observable_type=observable_type)
    base_env = TimeLimit(base_env, max_episode_steps=200)
    return base_env

# %%
def bugfix_seed():
    return int(np.random.randint(0, np.iinfo(np.uint32).max, dtype=np.uint32))

# %%
def make_envs(observable_type: env.ObservableType, n_envs=8):
    return make_vec_env(lambda: make_env(observable_type), n_envs=n_envs, seed=bugfix_seed())

# %%
observable_unstacked_env = make_envs(env.ObservableType.FULL)
observable_unstacked_env.observation_space
# Out:
# c:\Users\jhunt\miniconda3\envs\reinfocus\Lib\site-packages\numba\cuda\dispatcher.py:536: NumbaPerformanceWarning: Grid size 100 will likely result in GPU under-utilization due to low occupancy.
#   warn(NumbaPerformanceWarning(msg))
# Box(-1.0, 1.0, (3,), float32)

# %%
no_target_unstacked_env = make_envs(env.ObservableType.NO_TARGET)
no_target_unstacked_env.observation_space
# Out:
# Box(-1.0, 1.0, (2,), float32)

# %%
no_target_stacked_env = VecFrameStack(make_envs(env.ObservableType.NO_TARGET), 10)
no_target_stacked_env.observation_space
# Out:
# Box(-1.0, 1.0, (20,), float32)

# %%
def evaluate(model: BaseAlgorithm, eval_env: VecEnv):
    print(evaluate_policy(model, eval_env, n_eval_episodes=20, warn=False)[0])

def learn_and_evaluate(model: BaseAlgorithm, eval_env: VecEnv, n_steps: int = 5000, n_envs: int = 8):
    model.learn(n_steps * n_envs)
    evaluate(model, eval_env)

# %%
observable_unstacked_non_recurrent = PPO("MlpPolicy", observable_unstacked_env, verbose=1)
evaluate(observable_unstacked_non_recurrent, observable_unstacked_env)
# Out:
# Using cuda device
# -44.917272649999994

# %%
no_target_unstacked_non_recurrent = PPO("MlpPolicy", no_target_unstacked_env, verbose=1)
evaluate(no_target_unstacked_non_recurrent, no_target_unstacked_env)
# Out:
# Using cuda device
# -93.05241855

# %%
no_target_unstacked_recurrent = RecurrentPPO("MlpLstmPolicy", no_target_unstacked_env, verbose=1)
evaluate(no_target_unstacked_recurrent, no_target_unstacked_env)
# Out:
# Using cuda device
# -72.8706235

# %%
no_target_stacked_non_recurrent = PPO("MlpPolicy", no_target_stacked_env, verbose=1)
evaluate(no_target_stacked_non_recurrent, no_target_stacked_env)
# Out:
# Using cuda device
# -102.83595385000001

# %%
learn_and_evaluate(observable_unstacked_non_recurrent, observable_unstacked_env)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -88.2    |
# | time/              |          |
# |    fps             | 75       |
# |    iterations      | 1        |
# |    time_elapsed    | 217      |
# |    total_timesteps | 16384    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -82.1        |
# | time/                   |              |
# |    fps                  | 66           |
# |    iterations           | 2            |
# |    time_elapsed         | 496          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0097805215 |
# |    clip_fraction        | 0.121        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -0.00987     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.52         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0144      |
# |    std                  | 0.991        |
# |    value_loss           | 5.55         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -71         |
# | time/                   |             |
# |    fps                  | 65          |
# |    iterations           | 3           |
# |    time_elapsed         | 746         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.018866574 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.0105      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.965       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0203     |
# |    std                  | 0.923       |
# |    value_loss           | 2.63        |
# -----------------------------------------
# -44.047301950000005

# %%
learn_and_evaluate(no_target_unstacked_non_recurrent, no_target_unstacked_env)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -88.2    |
# | time/              |          |
# |    fps             | 75       |
# |    iterations      | 1        |
# |    time_elapsed    | 215      |
# |    total_timesteps | 16384    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -86.1       |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 2           |
# |    time_elapsed         | 442         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.007191565 |
# |    clip_fraction        | 0.0811      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | -0.0152     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.05        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00777    |
# |    std                  | 0.965       |
# |    value_loss           | 5.56        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -81.1       |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 3           |
# |    time_elapsed         | 670         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008483707 |
# |    clip_fraction        | 0.0906      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.000296    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.76        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00789    |
# |    std                  | 0.934       |
# |    value_loss           | 3.13        |
# -----------------------------------------
# -40.51235165

# %%
learn_and_evaluate(no_target_unstacked_recurrent, no_target_unstacked_env)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 74   |
# |    iterations      | 1    |
# |    time_elapsed    | 13   |
# |    total_timesteps | 1024 |
# -----------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -87.5        |
# | time/                   |              |
# |    fps                  | 56           |
# |    iterations           | 2            |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0018123561 |
# |    clip_fraction        | 0.000488     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.00169     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.12         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0014      |
# |    std                  | 0.994        |
# |    value_loss           | 14.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -87.5        |
# | time/                   |              |
# |    fps                  | 54           |
# |    iterations           | 3            |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 0.0014866645 |
# |    clip_fraction        | 9.77e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -0.133       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.34         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00171     |
# |    std                  | 0.993        |
# |    value_loss           | 15.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -84.3        |
# | time/                   |              |
# |    fps                  | 57           |
# |    iterations           | 4            |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0016539558 |
# |    clip_fraction        | 0.000586     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -1.79e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.62         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00123     |
# |    std                  | 0.992        |
# |    value_loss           | 17.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -82.2       |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 5           |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.004160489 |
# |    clip_fraction        | 0.0485      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | -0.145      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.79        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00619    |
# |    std                  | 0.99        |
# |    value_loss           | 12.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -82.2        |
# | time/                   |              |
# |    fps                  | 54           |
# |    iterations           | 6            |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0053326236 |
# |    clip_fraction        | 0.0512       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -0.137       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.28         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00629     |
# |    std                  | 0.985        |
# |    value_loss           | 11.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -79.7       |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 7           |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.010875248 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 3.58e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.4         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0125     |
# |    std                  | 0.982       |
# |    value_loss           | 8.67        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -79.9      |
# | time/                   |            |
# |    fps                  | 55         |
# |    iterations           | 8          |
# |    time_elapsed         | 147        |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.00925785 |
# |    clip_fraction        | 0.136      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.4       |
# |    explained_variance   | -0.0975    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.21       |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.00968   |
# |    std                  | 0.976      |
# |    value_loss           | 10.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -79.9       |
# | time/                   |             |
# |    fps                  | 54          |
# |    iterations           | 9           |
# |    time_elapsed         | 168         |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.016019834 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | -0.035      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.1         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0104     |
# |    std                  | 0.966       |
# |    value_loss           | 7.04        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -77.8       |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 10          |
# |    time_elapsed         | 183         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.015305889 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 2.98e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.946       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | 0.000387    |
# |    std                  | 0.955       |
# |    value_loss           | 4.92        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -76         |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 11          |
# |    time_elapsed         | 202         |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.006041306 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.0396     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.306       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00325    |
# |    std                  | 0.939       |
# |    value_loss           | 3.78        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -76         |
# | time/                   |             |
# |    fps                  | 54          |
# |    iterations           | 12          |
# |    time_elapsed         | 225         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.004728853 |
# |    clip_fraction        | 0.0951      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.0038     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.83        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00059    |
# |    std                  | 0.928       |
# |    value_loss           | 3.83        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -72.6       |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 13          |
# |    time_elapsed         | 240         |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.009348002 |
# |    clip_fraction        | 0.0671      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.45        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00382    |
# |    std                  | 0.921       |
# |    value_loss           | 3.49        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -72.6       |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 14          |
# |    time_elapsed         | 259         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.015902244 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -0.00727    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.17        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00262    |
# |    std                  | 0.917       |
# |    value_loss           | 3.86        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -70.3       |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 15          |
# |    time_elapsed         | 274         |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.005421426 |
# |    clip_fraction        | 0.0506      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.79        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00199    |
# |    std                  | 0.904       |
# |    value_loss           | 3.87        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -66.7        |
# | time/                   |              |
# |    fps                  | 55           |
# |    iterations           | 16           |
# |    time_elapsed         | 297          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0033188965 |
# |    clip_fraction        | 0.0348       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | -0.00244     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0532       |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00123     |
# |    std                  | 0.893        |
# |    value_loss           | 3.08         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -66.7        |
# | time/                   |              |
# |    fps                  | 54           |
# |    iterations           | 17           |
# |    time_elapsed         | 317          |
# |    total_timesteps      | 17408        |
# | train/                  |              |
# |    approx_kl            | 0.0053044846 |
# |    clip_fraction        | 0.0454       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | -0.0089      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.99         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00162     |
# |    std                  | 0.879        |
# |    value_loss           | 3.36         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -65.2        |
# | time/                   |              |
# |    fps                  | 55           |
# |    iterations           | 18           |
# |    time_elapsed         | 332          |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0009983552 |
# |    clip_fraction        | 0.0131       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.26         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00118     |
# |    std                  | 0.872        |
# |    value_loss           | 4.49         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 200           |
# |    ep_rew_mean          | -64.6         |
# | time/                   |               |
# |    fps                  | 55            |
# |    iterations           | 19            |
# |    time_elapsed         | 353           |
# |    total_timesteps      | 19456         |
# | train/                  |               |
# |    approx_kl            | 0.00082598417 |
# |    clip_fraction        | 0.00957       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.28         |
# |    explained_variance   | -0.0012       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.69          |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.000742     |
# |    std                  | 0.867         |
# |    value_loss           | 5.21          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -64.6        |
# | time/                   |              |
# |    fps                  | 54           |
# |    iterations           | 20           |
# |    time_elapsed         | 374          |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0023666704 |
# |    clip_fraction        | 0.0202       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | -0.00209     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.913        |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000787    |
# |    std                  | 0.867        |
# |    value_loss           | 7.23         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -64.3        |
# | time/                   |              |
# |    fps                  | 55           |
# |    iterations           | 21           |
# |    time_elapsed         | 389          |
# |    total_timesteps      | 21504        |
# | train/                  |              |
# |    approx_kl            | 0.0021595247 |
# |    clip_fraction        | 0.0261       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 47.7         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00105     |
# |    std                  | 0.872        |
# |    value_loss           | 22.1         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 200           |
# |    ep_rew_mean          | -65.2         |
# | time/                   |               |
# |    fps                  | 54            |
# |    iterations           | 22            |
# |    time_elapsed         | 410           |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 0.00060535007 |
# |    clip_fraction        | 0.00156       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.28         |
# |    explained_variance   | -0.000417     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.72          |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.000996     |
# |    std                  | 0.869         |
# |    value_loss           | 24.3          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -65.2        |
# | time/                   |              |
# |    fps                  | 54           |
# |    iterations           | 23           |
# |    time_elapsed         | 431          |
# |    total_timesteps      | 23552        |
# | train/                  |              |
# |    approx_kl            | 0.0013536674 |
# |    clip_fraction        | 0.0169       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.000341     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.5         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.001       |
# |    std                  | 0.868        |
# |    value_loss           | 30.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -63.6       |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 24          |
# |    time_elapsed         | 446         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.006586541 |
# |    clip_fraction        | 0.0281      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.92        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00038    |
# |    std                  | 0.868       |
# |    value_loss           | 12.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -62.2        |
# | time/                   |              |
# |    fps                  | 54           |
# |    iterations           | 25           |
# |    time_elapsed         | 466          |
# |    total_timesteps      | 25600        |
# | train/                  |              |
# |    approx_kl            | 0.0069046845 |
# |    clip_fraction        | 0.0287       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 6.71e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.27         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000348    |
# |    std                  | 0.871        |
# |    value_loss           | 13.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -62.2       |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 26          |
# |    time_elapsed         | 481         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.003964575 |
# |    clip_fraction        | 0.0306      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.57        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00179    |
# |    std                  | 0.869       |
# |    value_loss           | 19.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -59.7       |
# | time/                   |             |
# |    fps                  | 54          |
# |    iterations           | 27          |
# |    time_elapsed         | 504         |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.004243412 |
# |    clip_fraction        | 0.0803      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | -0.00171    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.47        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | 0.00164     |
# |    std                  | 0.871       |
# |    value_loss           | 4.05        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -59.7        |
# | time/                   |              |
# |    fps                  | 54           |
# |    iterations           | 28           |
# |    time_elapsed         | 525          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0054699066 |
# |    clip_fraction        | 0.064        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | -0.0012      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.59         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | 0.00205      |
# |    std                  | 0.87         |
# |    value_loss           | 4.49         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -58.5       |
# | time/                   |             |
# |    fps                  | 54          |
# |    iterations           | 29          |
# |    time_elapsed         | 540         |
# |    total_timesteps      | 29696       |
# | train/                  |             |
# |    approx_kl            | 0.003324389 |
# |    clip_fraction        | 0.0343      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | -3.58e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.22        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.000672   |
# |    std                  | 0.867       |
# |    value_loss           | 7.18        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -57.3        |
# | time/                   |              |
# |    fps                  | 54           |
# |    iterations           | 30           |
# |    time_elapsed         | 561          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0033815945 |
# |    clip_fraction        | 0.0494       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | -0.000251    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.92         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00336     |
# |    std                  | 0.869        |
# |    value_loss           | 5            |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -57.3       |
# | time/                   |             |
# |    fps                  | 54          |
# |    iterations           | 31          |
# |    time_elapsed         | 582         |
# |    total_timesteps      | 31744       |
# | train/                  |             |
# |    approx_kl            | 0.007271623 |
# |    clip_fraction        | 0.0605      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | -0.000361   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.32        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00464    |
# |    std                  | 0.864       |
# |    value_loss           | 5.49        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -57.8       |
# | time/                   |             |
# |    fps                  | 54          |
# |    iterations           | 32          |
# |    time_elapsed         | 596         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.004413916 |
# |    clip_fraction        | 0.0278      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 2.38e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.42        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.000168    |
# |    std                  | 0.856       |
# |    value_loss           | 11.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -59.4        |
# | time/                   |              |
# |    fps                  | 54           |
# |    iterations           | 33           |
# |    time_elapsed         | 618          |
# |    total_timesteps      | 33792        |
# | train/                  |              |
# |    approx_kl            | 0.0073934617 |
# |    clip_fraction        | 0.104        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | -0.000125    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.835        |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00723     |
# |    std                  | 0.851        |
# |    value_loss           | 10.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -59.4        |
# | time/                   |              |
# |    fps                  | 54           |
# |    iterations           | 34           |
# |    time_elapsed         | 639          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0023179825 |
# |    clip_fraction        | 0.0124       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 0.000174     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.678        |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00156     |
# |    std                  | 0.849        |
# |    value_loss           | 10.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -59.6        |
# | time/                   |              |
# |    fps                  | 54           |
# |    iterations           | 35           |
# |    time_elapsed         | 654          |
# |    total_timesteps      | 35840        |
# | train/                  |              |
# |    approx_kl            | 0.0047755055 |
# |    clip_fraction        | 0.0237       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.06         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00284     |
# |    std                  | 0.851        |
# |    value_loss           | 3.43         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -62.8        |
# | time/                   |              |
# |    fps                  | 54           |
# |    iterations           | 36           |
# |    time_elapsed         | 674          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0008704042 |
# |    clip_fraction        | 0.0104       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | -0.000865    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.32         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.000767    |
# |    std                  | 0.854        |
# |    value_loss           | 3.04         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -62.8       |
# | time/                   |             |
# |    fps                  | 54          |
# |    iterations           | 37          |
# |    time_elapsed         | 695         |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.004564743 |
# |    clip_fraction        | 0.0549      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.000403    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.111       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.000574    |
# |    std                  | 0.852       |
# |    value_loss           | 4.03        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -61.4        |
# | time/                   |              |
# |    fps                  | 54           |
# |    iterations           | 38           |
# |    time_elapsed         | 710          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0044485964 |
# |    clip_fraction        | 0.0429       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.06         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.000112    |
# |    std                  | 0.851        |
# |    value_loss           | 5.17         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -61.4        |
# | time/                   |              |
# |    fps                  | 54           |
# |    iterations           | 39           |
# |    time_elapsed         | 730          |
# |    total_timesteps      | 39936        |
# | train/                  |              |
# |    approx_kl            | 0.0009903999 |
# |    clip_fraction        | 0.00459      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | -0.000229    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.18         |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.000399    |
# |    std                  | 0.849        |
# |    value_loss           | 10.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -62.6        |
# | time/                   |              |
# |    fps                  | 54           |
# |    iterations           | 40           |
# |    time_elapsed         | 745          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0029019495 |
# |    clip_fraction        | 0.0282       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 2.38e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.246        |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.0015      |
# |    std                  | 0.845        |
# |    value_loss           | 18.7         |
# ------------------------------------------
# -72.23407305000002

# %%
learn_and_evaluate(no_target_stacked_non_recurrent, no_target_stacked_env)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -88.1    |
# | time/              |          |
# |    fps             | 74       |
# |    iterations      | 1        |
# |    time_elapsed    | 220      |
# |    total_timesteps | 16384    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -81.3       |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 2           |
# |    time_elapsed         | 447         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.012090378 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | -0.0449     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.34        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0133     |
# |    std                  | 0.959       |
# |    value_loss           | 5.56        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -73.5       |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 3           |
# |    time_elapsed         | 673         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.013434993 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -0.00387    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.11        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0164     |
# |    std                  | 0.916       |
# |    value_loss           | 2.8         |
# -----------------------------------------
# -47.246876650000004
