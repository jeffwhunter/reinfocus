# %%
import gymnasium as gym
import numpy as np

from gymnasium.envs.classic_control.cartpole import CartPoleEnv
from gymnasium.wrappers.time_limit import TimeLimit
from sb3_contrib import RecurrentPPO
from stable_baselines3 import PPO
from stable_baselines3.common.base_class import BaseAlgorithm
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.vec_env import VecEnv, VecFrameStack

# %%
class PartiallyObservableCartPole(CartPoleEnv):
    def __init__(self):
        super().__init__()
        high = np.array([self.x_threshold * 2, self.theta_threshold_radians * 2], dtype=np.float32)
        self.observation_space = gym.spaces.Box(-high, high, dtype=np.float32)

    @staticmethod
    def _pos_obs(full_obs):
        xpos, _, thetapos, _ = full_obs
        return xpos, thetapos

    def reset(self, seed=None, options=None):
        full_obs, _ = super().reset(seed=seed)
        return PartiallyObservableCartPole._pos_obs(full_obs), {}

    def step(self, action):
        full_obs, rew, term, trunc, info = super().step(action)
        return PartiallyObservableCartPole._pos_obs(full_obs), rew, term, trunc, info

    def close(self):
        pass

# %%
def make_env(observable: bool = True):
    if observable:
        base_env = CartPoleEnv()
    else:
        base_env = PartiallyObservableCartPole()
    base_env = TimeLimit(base_env, max_episode_steps=200)
    return base_env

# %%
def bugfix_seed():
    return int(np.random.randint(0, np.iinfo(np.uint32).max, dtype=np.uint32))

# %%
def make_envs(observable: bool = True, n_envs=8):
    return make_vec_env(lambda: make_env(observable), n_envs=n_envs, seed=bugfix_seed())

# %%
observable_unstacked_env = make_envs()
observable_unstacked_env.observation_space
# Out:
# Box([-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38], [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38], (4,), float32)

# %%
hidden_unstacked_env = make_envs(observable=False)
hidden_unstacked_env.observation_space
# Out:
# Box([-4.8        -0.41887903], [4.8        0.41887903], (2,), float32)

# %%
hidden_stacked_env = VecFrameStack(make_envs(observable=False), 10)
hidden_stacked_env.observation_space
# Out:
# Box([-4.8        -4.8        -4.8        -4.8        -4.8        -4.8
#  -4.8        -4.8        -4.8        -4.8        -0.41887903 -0.41887903
#  -0.41887903 -0.41887903 -0.41887903 -0.41887903 -0.41887903 -0.41887903
#  -0.41887903 -0.41887903], [4.8        4.8        4.8        4.8        4.8        4.8
#  4.8        4.8        4.8        4.8        0.41887903 0.41887903
#  0.41887903 0.41887903 0.41887903 0.41887903 0.41887903 0.41887903
#  0.41887903 0.41887903], (20,), float32)

# %%
def evaluate(model: BaseAlgorithm, eval_env: VecEnv):
    print(evaluate_policy(model, eval_env, n_eval_episodes=20, warn=False)[0])

def learn_and_evaluate(model: BaseAlgorithm, eval_env: VecEnv, n_steps: int = 5000, n_envs: int = 8):
    model.learn(n_steps * n_envs)
    evaluate(model, eval_env)

# %%
observable_unstacked_non_recurrent = PPO("MlpPolicy", observable_unstacked_env, verbose=1)
evaluate(observable_unstacked_non_recurrent, observable_unstacked_env)
# Out:
# Using cuda device
# 9.25

# %%
hidden_unstacked_non_recurrent = PPO("MlpPolicy", hidden_unstacked_env, verbose=1)
evaluate(hidden_unstacked_non_recurrent, hidden_unstacked_env)
# Out:
# Using cuda device
# 8.8

# %%
hidden_unstacked_recurrent = RecurrentPPO("MlpLstmPolicy", hidden_unstacked_env, verbose=1)
evaluate(hidden_unstacked_recurrent, hidden_unstacked_env)
# Out:
# Using cuda device
# 9.25

# %%
hidden_stacked_non_recurrent = PPO("MlpPolicy", hidden_stacked_env, verbose=1)
evaluate(hidden_stacked_non_recurrent, hidden_stacked_env)
# Out:
# Using cuda device
# 9.6

# %%
learn_and_evaluate(observable_unstacked_non_recurrent, observable_unstacked_env)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.8     |
# |    ep_rew_mean     | 22.8     |
# | time/              |          |
# |    fps             | 6133     |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 16384    |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 34.3       |
# |    ep_rew_mean          | 34.3       |
# | time/                   |            |
# |    fps                  | 2278       |
# |    iterations           | 2          |
# |    time_elapsed         | 14         |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.01571438 |
# |    clip_fraction        | 0.264      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.68      |
# |    explained_variance   | 0.000233   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.35       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0278    |
# |    value_loss           | 13.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 91          |
# |    ep_rew_mean          | 91          |
# | time/                   |             |
# |    fps                  | 1922        |
# |    iterations           | 3           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.019448835 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.638      |
# |    explained_variance   | 0.398       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.8        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0387     |
# |    value_loss           | 26.8        |
# -----------------------------------------
# 200.0

# %%
learn_and_evaluate(hidden_unstacked_non_recurrent, hidden_unstacked_env)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.1     |
# |    ep_rew_mean     | 22.1     |
# | time/              |          |
# |    fps             | 6014     |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 16384    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.5        |
# |    ep_rew_mean          | 26.5        |
# | time/                   |             |
# |    fps                  | 2414        |
# |    iterations           | 2           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.006602927 |
# |    clip_fraction        | 0.0795      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.688      |
# |    explained_variance   | 0.000113    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.93        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 19.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29          |
# |    ep_rew_mean          | 29          |
# | time/                   |             |
# |    fps                  | 1976        |
# |    iterations           | 3           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008093199 |
# |    clip_fraction        | 0.0991      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.668      |
# |    explained_variance   | 0.281       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.2        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.014      |
# |    value_loss           | 29          |
# -----------------------------------------
# 42.1

# %%
learn_and_evaluate(hidden_unstacked_recurrent, hidden_unstacked_env)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.7     |
# |    ep_rew_mean     | 21.7     |
# | time/              |          |
# |    fps             | 2845     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1024     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22.4         |
# |    ep_rew_mean          | 22.4         |
# | time/                   |              |
# |    fps                  | 434          |
# |    iterations           | 2            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0018576242 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.693       |
# |    explained_variance   | 0.000757     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.1         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.000797    |
# |    value_loss           | 44.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.1        |
# |    ep_rew_mean          | 22.1        |
# | time/                   |             |
# |    fps                  | 353         |
# |    iterations           | 3           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.001429857 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.692      |
# |    explained_variance   | -0.119      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.4        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00121    |
# |    value_loss           | 44.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22.6         |
# |    ep_rew_mean          | 22.6         |
# | time/                   |              |
# |    fps                  | 330          |
# |    iterations           | 4            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0026147105 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.692       |
# |    explained_variance   | -0.0616      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.1         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000142    |
# |    value_loss           | 40.9         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 22.9          |
# |    ep_rew_mean          | 22.9          |
# | time/                   |               |
# |    fps                  | 315           |
# |    iterations           | 5             |
# |    time_elapsed         | 16            |
# |    total_timesteps      | 5120          |
# | train/                  |               |
# |    approx_kl            | 0.00042909977 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.686        |
# |    explained_variance   | -0.0135       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 16.2          |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.000562     |
# |    value_loss           | 44.5          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.5        |
# |    ep_rew_mean          | 24.5        |
# | time/                   |             |
# |    fps                  | 295         |
# |    iterations           | 6           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.020096136 |
# |    clip_fraction        | 0.0507      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.691      |
# |    explained_variance   | -0.00288    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20          |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00173    |
# |    value_loss           | 57.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 25           |
# |    ep_rew_mean          | 25           |
# | time/                   |              |
# |    fps                  | 288          |
# |    iterations           | 7            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 7168         |
# | train/                  |              |
# |    approx_kl            | 0.0032113616 |
# |    clip_fraction        | 0.00684      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.691       |
# |    explained_variance   | -0.00235     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.9         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00369     |
# |    value_loss           | 51.1         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 24.5          |
# |    ep_rew_mean          | 24.5          |
# | time/                   |               |
# |    fps                  | 285           |
# |    iterations           | 8             |
# |    time_elapsed         | 28            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.00068909535 |
# |    clip_fraction        | 0.00332       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.686        |
# |    explained_variance   | -0.00135      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 22.8          |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -0.000533     |
# |    value_loss           | 49.8          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 23.2         |
# |    ep_rew_mean          | 23.2         |
# | time/                   |              |
# |    fps                  | 282          |
# |    iterations           | 9            |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 9216         |
# | train/                  |              |
# |    approx_kl            | 0.0056187273 |
# |    clip_fraction        | 0.0576       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.686       |
# |    explained_variance   | -0.00105     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35.7         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00673     |
# |    value_loss           | 49.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 24.9         |
# |    ep_rew_mean          | 24.9         |
# | time/                   |              |
# |    fps                  | 278          |
# |    iterations           | 10           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0018185384 |
# |    clip_fraction        | 0.0239       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.677       |
# |    explained_variance   | -0.000502    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 36.7         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.0047      |
# |    value_loss           | 59.1         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 26.4       |
# |    ep_rew_mean          | 26.4       |
# | time/                   |            |
# |    fps                  | 269        |
# |    iterations           | 11         |
# |    time_elapsed         | 41         |
# |    total_timesteps      | 11264      |
# | train/                  |            |
# |    approx_kl            | 0.00555221 |
# |    clip_fraction        | 0.0732     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.652     |
# |    explained_variance   | -0.000324  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 24.5       |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0013    |
# |    value_loss           | 65.6       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.3         |
# |    ep_rew_mean          | 28.3         |
# | time/                   |              |
# |    fps                  | 263          |
# |    iterations           | 12           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0048686494 |
# |    clip_fraction        | 0.0479       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.654       |
# |    explained_variance   | -0.000225    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 38.6         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0059      |
# |    value_loss           | 67.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.2        |
# |    ep_rew_mean          | 30.2        |
# | time/                   |             |
# |    fps                  | 262         |
# |    iterations           | 13          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.012659291 |
# |    clip_fraction        | 0.0771      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.658      |
# |    explained_variance   | -0.000269   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.7        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 60.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 31.6        |
# |    ep_rew_mean          | 31.6        |
# | time/                   |             |
# |    fps                  | 256         |
# |    iterations           | 14          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.009870237 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.621      |
# |    explained_variance   | -0.000156   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.5        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.000433   |
# |    value_loss           | 69.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 32.3        |
# |    ep_rew_mean          | 32.3        |
# | time/                   |             |
# |    fps                  | 252         |
# |    iterations           | 15          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.008815125 |
# |    clip_fraction        | 0.0501      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.64       |
# |    explained_variance   | -0.000193   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.8        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00583    |
# |    value_loss           | 71.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 32.4         |
# |    ep_rew_mean          | 32.4         |
# | time/                   |              |
# |    fps                  | 249          |
# |    iterations           | 16           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0027262466 |
# |    clip_fraction        | 0.0236       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.605       |
# |    explained_variance   | -0.000139    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35           |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00412     |
# |    value_loss           | 74           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 33.7         |
# |    ep_rew_mean          | 33.7         |
# | time/                   |              |
# |    fps                  | 245          |
# |    iterations           | 17           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 17408        |
# | train/                  |              |
# |    approx_kl            | 0.0033751726 |
# |    clip_fraction        | 0.0292       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.604       |
# |    explained_variance   | -7.08e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35.4         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00479     |
# |    value_loss           | 77.3         |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 37.4      |
# |    ep_rew_mean          | 37.4      |
# | time/                   |           |
# |    fps                  | 243       |
# |    iterations           | 18        |
# |    time_elapsed         | 75        |
# |    total_timesteps      | 18432     |
# | train/                  |           |
# |    approx_kl            | 0.0097869 |
# |    clip_fraction        | 0.122     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.591    |
# |    explained_variance   | -0.000104 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 39.4      |
# |    n_updates            | 170       |
# |    policy_gradient_loss | -0.0106   |
# |    value_loss           | 75.9      |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 41.8         |
# |    ep_rew_mean          | 41.8         |
# | time/                   |              |
# |    fps                  | 237          |
# |    iterations           | 19           |
# |    time_elapsed         | 81           |
# |    total_timesteps      | 19456        |
# | train/                  |              |
# |    approx_kl            | 0.0026704115 |
# |    clip_fraction        | 0.0587       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.582       |
# |    explained_variance   | -3.6e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 40.1         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00631     |
# |    value_loss           | 96.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.9        |
# |    ep_rew_mean          | 47.9        |
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 20          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.004167716 |
# |    clip_fraction        | 0.0348      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.558      |
# |    explained_variance   | -2.99e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46.3        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00658    |
# |    value_loss           | 97.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.5        |
# |    ep_rew_mean          | 51.5        |
# | time/                   |             |
# |    fps                  | 229         |
# |    iterations           | 21          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.008685431 |
# |    clip_fraction        | 0.0321      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.568      |
# |    explained_variance   | -1.91e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46.3        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00577    |
# |    value_loss           | 99.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 58.6        |
# |    ep_rew_mean          | 58.6        |
# | time/                   |             |
# |    fps                  | 227         |
# |    iterations           | 22          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.009613283 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.562      |
# |    explained_variance   | -2.07e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.4        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00682    |
# |    value_loss           | 104         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 63.8       |
# |    ep_rew_mean          | 63.8       |
# | time/                   |            |
# |    fps                  | 225        |
# |    iterations           | 23         |
# |    time_elapsed         | 104        |
# |    total_timesteps      | 23552      |
# | train/                  |            |
# |    approx_kl            | 0.02248853 |
# |    clip_fraction        | 0.108      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.559     |
# |    explained_variance   | -3.02e-05  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 38.4       |
# |    n_updates            | 220        |
# |    policy_gradient_loss | 0.00445    |
# |    value_loss           | 98.1       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 68.8        |
# |    ep_rew_mean          | 68.8        |
# | time/                   |             |
# |    fps                  | 222         |
# |    iterations           | 24          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.007465657 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.507      |
# |    explained_variance   | -2.66e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 63.8        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.014       |
# |    value_loss           | 108         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 76.3         |
# |    ep_rew_mean          | 76.3         |
# | time/                   |              |
# |    fps                  | 218          |
# |    iterations           | 25           |
# |    time_elapsed         | 117          |
# |    total_timesteps      | 25600        |
# | train/                  |              |
# |    approx_kl            | 0.0048254794 |
# |    clip_fraction        | 0.0556       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.542       |
# |    explained_variance   | -2.53e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 58.2         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00012     |
# |    value_loss           | 108          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85.6        |
# |    ep_rew_mean          | 85.6        |
# | time/                   |             |
# |    fps                  | 217         |
# |    iterations           | 26          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.005182857 |
# |    clip_fraction        | 0.0304      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.52       |
# |    explained_variance   | -5.01e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.7        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00092    |
# |    value_loss           | 101         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 89.4        |
# |    ep_rew_mean          | 89.4        |
# | time/                   |             |
# |    fps                  | 214         |
# |    iterations           | 27          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.007027637 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.504      |
# |    explained_variance   | -1.59e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 67.9        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | 0.0148      |
# |    value_loss           | 99.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 94.8         |
# |    ep_rew_mean          | 94.8         |
# | time/                   |              |
# |    fps                  | 213          |
# |    iterations           | 28           |
# |    time_elapsed         | 134          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0060390756 |
# |    clip_fraction        | 0.104        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.504       |
# |    explained_variance   | -1.12e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 67.9         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.000131    |
# |    value_loss           | 106          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 103          |
# |    ep_rew_mean          | 103          |
# | time/                   |              |
# |    fps                  | 210          |
# |    iterations           | 29           |
# |    time_elapsed         | 140          |
# |    total_timesteps      | 29696        |
# | train/                  |              |
# |    approx_kl            | 0.0078012715 |
# |    clip_fraction        | 0.175        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.525       |
# |    explained_variance   | -2.34e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 36.7         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | 0.00624      |
# |    value_loss           | 107          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 105         |
# |    ep_rew_mean          | 105         |
# | time/                   |             |
# |    fps                  | 208         |
# |    iterations           | 30          |
# |    time_elapsed         | 147         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008771474 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.51       |
# |    explained_variance   | -1.07e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.8        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.00372     |
# |    value_loss           | 107         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 110        |
# |    ep_rew_mean          | 110        |
# | time/                   |            |
# |    fps                  | 207        |
# |    iterations           | 31         |
# |    time_elapsed         | 153        |
# |    total_timesteps      | 31744      |
# | train/                  |            |
# |    approx_kl            | 0.01884374 |
# |    clip_fraction        | 0.204      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.507     |
# |    explained_variance   | -1.26e-05  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 37.1       |
# |    n_updates            | 300        |
# |    policy_gradient_loss | 0.00634    |
# |    value_loss           | 101        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 113         |
# |    ep_rew_mean          | 113         |
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 32          |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008267154 |
# |    clip_fraction        | 0.0611      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.47       |
# |    explained_variance   | -9.78e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 55.1        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00343    |
# |    value_loss           | 108         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 118         |
# |    ep_rew_mean          | 118         |
# | time/                   |             |
# |    fps                  | 206         |
# |    iterations           | 33          |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 33792       |
# | train/                  |             |
# |    approx_kl            | 0.014269305 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.462      |
# |    explained_variance   | -8.11e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 55.9        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00576    |
# |    value_loss           | 96.1        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 119       |
# |    ep_rew_mean          | 119       |
# | time/                   |           |
# |    fps                  | 205       |
# |    iterations           | 34        |
# |    time_elapsed         | 169       |
# |    total_timesteps      | 34816     |
# | train/                  |           |
# |    approx_kl            | 0.5760568 |
# |    clip_fraction        | 0.48      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.325    |
# |    explained_variance   | -1.17e-05 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 29.3      |
# |    n_updates            | 330       |
# |    policy_gradient_loss | 0.0893    |
# |    value_loss           | 94.9      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 117         |
# |    ep_rew_mean          | 117         |
# | time/                   |             |
# |    fps                  | 203         |
# |    iterations           | 35          |
# |    time_elapsed         | 176         |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.008949144 |
# |    clip_fraction        | 0.0437      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.465      |
# |    explained_variance   | -4.2e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 55          |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00494    |
# |    value_loss           | 203         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 110         |
# |    ep_rew_mean          | 110         |
# | time/                   |             |
# |    fps                  | 201         |
# |    iterations           | 36          |
# |    time_elapsed         | 182         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.007569743 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.457      |
# |    explained_variance   | -1.53e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 56.9        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00117    |
# |    value_loss           | 146         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 105         |
# |    ep_rew_mean          | 105         |
# | time/                   |             |
# |    fps                  | 200         |
# |    iterations           | 37          |
# |    time_elapsed         | 189         |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.013637325 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.492      |
# |    explained_variance   | -1.28e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 86.1        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 7.89e-05    |
# |    value_loss           | 136         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 99.9       |
# |    ep_rew_mean          | 99.9       |
# | time/                   |            |
# |    fps                  | 198        |
# |    iterations           | 38         |
# |    time_elapsed         | 196        |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.04555808 |
# |    clip_fraction        | 0.177      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.48      |
# |    explained_variance   | -1.31e-05  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 105        |
# |    n_updates            | 370        |
# |    policy_gradient_loss | 0.000316   |
# |    value_loss           | 168        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 94.4         |
# |    ep_rew_mean          | 94.4         |
# | time/                   |              |
# |    fps                  | 197          |
# |    iterations           | 39           |
# |    time_elapsed         | 202          |
# |    total_timesteps      | 39936        |
# | train/                  |              |
# |    approx_kl            | 0.0075046537 |
# |    clip_fraction        | 0.0415       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.513       |
# |    explained_variance   | -1.47e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 62.3         |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.000752    |
# |    value_loss           | 157          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 93.8        |
# |    ep_rew_mean          | 93.8        |
# | time/                   |             |
# |    fps                  | 195         |
# |    iterations           | 40          |
# |    time_elapsed         | 209         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.004513912 |
# |    clip_fraction        | 0.0989      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.498      |
# |    explained_variance   | -1.91e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 138         |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.000695   |
# |    value_loss           | 167         |
# -----------------------------------------
# 138.2

# %%
learn_and_evaluate(hidden_stacked_non_recurrent, hidden_stacked_env)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.8     |
# |    ep_rew_mean     | 21.8     |
# | time/              |          |
# |    fps             | 6204     |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 16384    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 25.7         |
# |    ep_rew_mean          | 25.7         |
# | time/                   |              |
# |    fps                  | 2364         |
# |    iterations           | 2            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0065383962 |
# |    clip_fraction        | 0.0775       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.687       |
# |    explained_variance   | -0.00131     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.06         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0129      |
# |    value_loss           | 16.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 36          |
# |    ep_rew_mean          | 36          |
# | time/                   |             |
# |    fps                  | 1980        |
# |    iterations           | 3           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.012486149 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.663      |
# |    explained_variance   | 0.318       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.75        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0191     |
# |    value_loss           | 28.1        |
# -----------------------------------------
# 200.0
