# %%
from matplotlib import pyplot

from reinfocus.environment import focus_environment

# %%
e = focus_environment.FocusEnvironment(render_mode="rgb_array")
# Out:
# c:\Users\jhunt\miniconda3\envs\reinfocus\Lib\site-packages\numba\cuda\dispatcher.py:536: NumbaPerformanceWarning: Grid size 100 will likely result in GPU under-utilization due to low occupancy.
#   warn(NumbaPerformanceWarning(msg))

# %%
e.action_space
# Out:
# Box(-1.0, 1.0, (1,), float32)

# %%
e.observation_space
# Out:
# Box(-1.0, 1.0, (3,), float32)

# %%
e.reset()
# Out:
# (array([-0.16993226, -0.36109242,  0.24951445], dtype=float32), {})

# %%
pyplot.imshow(e.render())

# %%
e.step(-1)
# Out:
# (array([-0.16993226, -0.5610924 , -0.6448328 ], dtype=float32),
#  -0.19558006525039673,
#  False,
#  False,
#  {})

# %%
pyplot.imshow(e.render())

# %%
o = e.step(1.0)[0]

# %%
pyplot.imshow(e.render())

# %%
e.step((o[focus_environment.TARGET] - o[focus_environment.LENS]) / 2)
# Out:
# (array([-0.16993226, -0.3419763 ,  0.361433  ], dtype=float32),
#  -0.0860220268368721,
#  False,
#  False,
#  {})

# %%
pyplot.imshow(e.render())
