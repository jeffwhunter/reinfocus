# %%
from matplotlib import pyplot

from reinfocus.environment import focus_environment

# %%
e = focus_environment.SimpleDiscreteEnviroment(render_mode="rgb_array")

# %%
e.action_space
# Out:
# Discrete(7)

# %%
e.observation_space
# Out:
# Box(-1.0, 1.0, (2,), float32)

# %%
e.reset()
# Out:
# (array([-0.7830757,  0.6298269], dtype=float32), {})

# %%
def show(image):
    _, ax = pyplot.subplots(figsize=(14, 14))
    ax.axis('off')
    ax.imshow(image)
    pyplot.tight_layout()

# %%
show(e.render())

# %%
e.step(6)
# Out:
# (array([-0.98307574, -0.08695391], dtype=float32),
#  -0.1844394683837891,
#  False,
#  False,
#  {})

# %%
show(e.render())

# %%
e.step(4)
show(e.render())

# %%
e.step(2)
show(e.render())

# %%
e.step(1)
e.step(3)
e.step(5)
show(e.render())
