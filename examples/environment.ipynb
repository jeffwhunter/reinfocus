# %%
from matplotlib import pyplot

from reinfocus.environment import focus_environment
from reinfocus.environment.types import OI

# %%
e = focus_environment.SimpleDiscreteEnviroment(render_mode="rgb_array")

# %%
e.action_space
# Out:
# Discrete(7)

# %%
e.observation_space
# Out:
# Box(-1.0, 1.0, (2,), float32)

# %%
e.reset()
# Out:
# (array([0.87498665, 0.99801797], dtype=float32), {})

# %%
pyplot.imshow(e.render())

# %%
e.step(6)
# Out:
# (array([0.67498666, 0.87879354], dtype=float32),
#  -0.09523028135299683,
#  False,
#  False,
#  {})

# %%
pyplot.imshow(e.render())

# %%
e.step(4)
pyplot.imshow(e.render())

# %%
e.step(2)
pyplot.imshow(e.render())

# %%
e.step(1)
e.step(3)
e.step(5)
pyplot.imshow(e.render())
