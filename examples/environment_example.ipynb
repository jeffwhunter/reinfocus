# %%
import matplotlib.pyplot as plt

from reinfocus.learning import focus_environment as env

# %%
e = env.FocusEnvironment(render_mode="rgb_array")
# Out:
# c:\Users\jhunt\miniconda3\envs\reinfocus\Lib\site-packages\numba\cuda\dispatcher.py:536: NumbaPerformanceWarning: Grid size 100 will likely result in GPU under-utilization due to low occupancy.
#   warn(NumbaPerformanceWarning(msg))

# %%
e.action_space
# Out:
# Box(-1.0, 1.0, (1,), float32)

# %%
e.observation_space
# Out:
# Box(-1.0, 1.0, (3,), float32)

# %%
e.reset()
# Out:
# (array([-0.44160447, -0.6131736 , -0.3333672 ], dtype=float32), {})

# %%
plt.imshow(e.render())

# %%
e.step(-1)
# Out:
# (array([-0.44160447, -1.        , -0.9951636 ], dtype=float32),
#  -0.2791977524757385,
#  False,
#  False,
#  {})

# %%
plt.imshow(e.render())

# %%
o = e.step(1.0)[0]

# %%
plt.imshow(e.render())

# %%
e.step((o[env.TARGET] - o[env.LENS]) / 2)
# Out:
# (array([-0.44160447, -0.4416045 ,  0.9998855 ], dtype=float32),
#  -1.4901161193847656e-08,
#  False,
#  False,
#  {})

# %%
plt.imshow(e.render())
